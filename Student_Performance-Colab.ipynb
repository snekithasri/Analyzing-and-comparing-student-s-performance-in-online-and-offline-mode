# %% [markdown]
# # Student Performance in E-Learning Envirnoment

# %% [markdown]
# Importing packages

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Reading Data

# %%
data=pd.read_csv('msc2019b.csv')

# %%
data.head()
# Out:
#    Roll number         Name Department  Gender  Age  sem1_marks   sem2_marks   \
# 0      1931001    Aathish M         SS    Male   19         8.70         7.90
# 1      1931002     Adarsh S         SS    Male   19         7.58         7.70
# 2      1931003    R. Ahalya         SS  Female   20         8.75         8.57
# 3      1931004      Ajhay V         SS    Male   20         8.38         8.45
# 4      1931005  D.A.Akshaya         SS  Female   19         8.08         8.48
#
#    sem3_marks   sem4_marks  Which device you use more frequently  ...  \
# 0         9.10         8.90                               Laptop  ...
# 1         9.09         8.73                               Laptop  ...
# 2         9.55         9.50                               Laptop  ...
# 3         8.57         8.77                                Phone  ...
# 4         8.77         8.64                               Laptop  ...
#
#   After COVID-19: I have fixed hours for bedtime and wake-up.   \
# 0                                              Agree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                     Strongly Agree
#
#   Staying home for long periods of time leads to lethargy and laziness.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 0                                          Uncertain
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The psychological element is a key factor in the success of the educational process.  \
# 0                                     Strongly Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                           Disagree
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                           Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Taking quizzes and exams online from home was not comfortable and made me nervous.
# 0                                  Strongly Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
# [5 rows x 28 columns]

# %%
data.tail()
# Out:
#      Roll number        Name Department  Gender  Age  sem1_marks   \
# 162      1934049      Subash    AI & ML    Male   20         7.09
# 163      1934051    Surya RE    AI & ML    Male   21         6.91
# 164      1934052    TANUJA A    AI & ML  Female   19         7.05
# 165      1934054  Vaishali K    AI & ML  Female   20         7.18
# 166      1934055    Varsha B    AI & ML  Female   19         7.45
#
#      sem2_marks   sem3_marks   sem4_marks   \
# 162         8.52         8.36         8.14
# 163         8.24         8.55         8.10
# 164         8.71         8.05         8.10
# 165         8.62         9.05         8.14
# 166         8.81         8.86         8.62
#
#     Which device you use more frequently  ...  \
# 162                               Laptop  ...
# 163                               Laptop  ...
# 164                                Phone  ...
# 165                                Phone  ...
# 166                                Phone  ...
#
#     After COVID-19: I have fixed hours for bedtime and wake-up.   \
# 162                                          Uncertain
# 163                                           Disagree
# 164                                           Disagree
# 165                                          Uncertain
# 166                                  Strongly Disagree
#
#     Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                              Agree
# 166                                     Strongly Agree
#
#     The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     Staying home for long periods of time leads to lethargy and laziness.  \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     The psychological element is a key factor in the success of the educational process.  \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                              Agree
# 166                                     Strongly Agree
#
#     I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 162                                          Uncertain
# 163                                  Strongly Disagree
# 164                                  Strongly Disagree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     Taking quizzes and exams online from home was not comfortable and made me nervous.
# 162                                              Agree
# 163                                  Strongly Disagree
# 164                                  Strongly Disagree
# 165                                              Agree
# 166                                     Strongly Agree
#
# [5 rows x 28 columns]

# %% [markdown]
# Pre-Processing

# %%
#Checking of Missing Values
data.isnull().sum()
# Out:
# Roll number                                                                                                                               0
# Name                                                                                                                                      0
# Department                                                                                                                                0
# Gender                                                                                                                                    0
# Age                                                                                                                                       0
# sem1_marks                                                                                                                                0
# sem2_marks                                                                                                                                0
# sem3_marks                                                                                                                                0
# sem4_marks                                                                                                                                0
# Which device you use more frequently                                                                                                      0
# How you study before covid , using printed notes or online notes                                                                          0
# How you study after covid , using printed notes or online notes                                                                           0
# Before COVID-19: How much time do you spend using the digital tools in learning (in hrs) ?                                                0
# After COVID-19: How much time do you spend using the digital tools in learning (in hrs) ?                                                 0
# Before COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.                                                          0
# After COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.                                                           0
#  When I use the mobile phone, tablet or laptop in e-learning, I cannot concentrate and I am distracted.                                   0
# Before COVID-19: I have fixed hours for bedtime and wake-up.                                                                              0
# After COVID-19: I have fixed hours for bedtime and wake-up.                                                                               0
# Continuous exposure to electronic screens in online learning is tiring and exhausting                                                     0
# The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?    0
# Staying home for long periods of time leads to lethargy and laziness.                                                                     0
# Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.                                                       0
# The psychological element is a key factor in the success of the educational process.                                                      0
# I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.                         0
# The volume of assignments via e-learning led to confusion, frustration and poor performance.                                              0
# Face-to-face interaction contributes significantly to boosting students’ academic achievement.                                            0
# Taking quizzes and exams online from home was not comfortable and made me nervous.                                                        0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Roll number', 'Name', 'Department', 'Gender', 'Age', 'sem1_marks ',
#        'sem2_marks ', 'sem3_marks ', 'sem4_marks ',
#        'Which device you use more frequently',
#        'How you study before covid , using printed notes or online notes',
#        'How you study after covid , using printed notes or online notes',
#        'Before COVID-19: How much time do you spend using the digital tools in learning (in hrs) ? ',
#        'After COVID-19: How much time do you spend using the digital tools in learning (in hrs) ? ',
#        'Before COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.',
#        'After COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.',
#        ' When I use the mobile phone, tablet or laptop in e-learning, I cannot concentrate and I am distracted.',
#        'Before COVID-19: I have fixed hours for bedtime and wake-up. ',
#        'After COVID-19: I have fixed hours for bedtime and wake-up. ',
#        'Continuous exposure to electronic screens in online learning is tiring and exhausting',
#        'The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?',
#        'Staying home for long periods of time leads to lethargy and laziness.',
#        'Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.',
#        'The psychological element is a key factor in the success of the educational process.',
#        'I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.',
#        'The volume of assignments via e-learning led to confusion, frustration and poor performance. ',
#        'Face-to-face interaction contributes significantly to boosting students’ academic achievement.',
#        'Taking quizzes and exams online from home was not comfortable and made me nervous.'],
#       dtype='object')

# %% [markdown]
# No Missing Values

# %%
#Binning
bins = [6.5,7.0,7.5,8.0,8.5,9.0,9.5,10.0]

group_names = ['>6.5','>7.0','>7.5','>8.0','>8.5','>9.0','>9.5']

data['grade_sep']= pd.cut(data['sem1_marks '],bins,labels=group_names)
data.head()
# Out:
#    Roll number         Name Department  Gender  Age  sem1_marks   sem2_marks   \
# 0      1931001    Aathish M         SS    Male   19         8.70         7.90
# 1      1931002     Adarsh S         SS    Male   19         7.58         7.70
# 2      1931003    R. Ahalya         SS  Female   20         8.75         8.57
# 3      1931004      Ajhay V         SS    Male   20         8.38         8.45
# 4      1931005  D.A.Akshaya         SS  Female   19         8.08         8.48
#
#    sem3_marks   sem4_marks  Which device you use more frequently  ...  \
# 0         9.10         8.90                               Laptop  ...
# 1         9.09         8.73                               Laptop  ...
# 2         9.55         9.50                               Laptop  ...
# 3         8.57         8.77                                Phone  ...
# 4         8.77         8.64                               Laptop  ...
#
#   Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                     Strongly Agree
#
#   Staying home for long periods of time leads to lethargy and laziness.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 0                                          Uncertain
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The psychological element is a key factor in the success of the educational process.  \
# 0                                     Strongly Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                           Disagree
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                           Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Taking quizzes and exams online from home was not comfortable and made me nervous.  \
# 0                                  Strongly Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   grade_sep
# 0      >8.5
# 1      >7.5
# 2      >8.5
# 3      >8.0
# 4      >8.0
#
# [5 rows x 29 columns]

# %%
#Histogram for Binned Values
df = pd.DataFrame(data)
fig = plt.figure(figsize =(8,6))
plt.hist(df['grade_sep'],bins=7)
plt.show()

# %%
# OFFLINE EXAM - DISTRIBUTION PLOT

plt.figure(4, figsize=(6,10))

plt.subplot(211)
sn.distplot(df['sem1_marks '])

plt.subplot(212)
sn.distplot(df['sem2_marks '])

plt.show()

# %%
# ONLINE EXAM - DISTRIBUTION PLOT

plt.figure(2, figsize=(6,10))

plt.subplot(211)
sn.distplot(df['sem3_marks '])

plt.subplot(212)
sn.distplot(df['sem4_marks '])

plt.show()

# %% [markdown]
# From above graphs of offilne and online exams, we can easily give interfrence that :
#     1. Semester 1 scores are normally distributed and semester 2 score is also to some extend normally distributed,
#        where as semester 3 is not normally distributed and semester 4 is also not normally distibuted but it is compartively better than semester 3.
#     therefore, there is lot of randomness in semester 3 then following semester 4 and 2.
#
#     Randomness in Scores :
#         max randomess > Semester 3 >semester 4 > semester 2 > Semester 1 > Min Randomness
# So, Online exam have lot of randomness , where offline exams gives stable score.
#
# possible reasons :
#     1. Cheating in online exams
#     2. improper understanding or contact between student and staff
#     3. Uneven markings
#     4. Online Gradings
#     5. ....
# Overall ; Lack of Transparency from both sides.

# %%
#BoxPlot for Each Semester

data = [df['sem1_marks '],df['sem2_marks '],df['sem3_marks '],df['sem4_marks ']]
#Figure Size
fig = plt.figure(figsize =(12, 8))
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
plt.show()

# %%
df.sample(frac=0.05)
# Out:
#      Roll number                     Name Department  Gender  Age  \
# 16       1931019  Midhun Chakkaravarthy K         SS    Male   19
# 49       1932005               Ashmitha S         DS  Female   20
# 40       1931047          Swarnalakshmi D         SS  Female   20
# 130      1934014             Kalanithi T     AI & ML    Male   19
# 89       1932049             Somasunder S         DS    Male   20
# 106      1933012             Ezhilmathi.K        DCS  Female   19
# 7        1931009                     Guna         SS    Male   20
# 29       1931033                  Sangavi         SS  Female   19
#
#      sem1_marks   sem2_marks   sem3_marks   sem4_marks   \
# 16          7.54         7.91         9.09         8.95
# 49          9.54         9.17         9.71         9.33
# 40          8.33         8.13         9.32         9.18
# 130         6.95         8.62         7.45         8.29
# 89          8.96         8.65         9.43         9.19
# 106         8.27         8.35         9.35         9.50
# 7           8.08         8.13         8.91         8.82
# 29          7.67         7.90         8.50         9.00
#
#     Which device you use more frequently  ...  \
# 16                                Laptop  ...
# 49                                 Phone  ...
# 40                                Laptop  ...
# 130                               Others  ...
# 89                                 Phone  ...
# 106                                Phone  ...
# 7                                 Laptop  ...
# 29                                Laptop  ...
#
#     Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 16                                               Agree
# 49                                           Uncertain
# 40                                      Strongly Agree
# 130                                              Agree
# 89                                               Agree
# 106                                     Strongly Agree
# 7                                                Agree
# 29                                           Uncertain
#
#     The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 16                                               Agree
# 49                                               Agree
# 40                                               Agree
# 130                                              Agree
# 89                                               Agree
# 106                                     Strongly Agree
# 7                                       Strongly Agree
# 29                                           Uncertain
#
#     Staying home for long periods of time leads to lethargy and laziness.  \
# 16                                      Strongly Agree
# 49                                            Disagree
# 40                                               Agree
# 130                                              Agree
# 89                                               Agree
# 106                                     Strongly Agree
# 7                                                Agree
# 29                                           Uncertain
#
#     Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 16                                               Agree
# 49                                           Uncertain
# 40                                      Strongly Agree
# 130                                  Strongly Disagree
# 89                                               Agree
# 106                                              Agree
# 7                                                Agree
# 29                                               Agree
#
#     The psychological element is a key factor in the success of the educational process.  \
# 16                                           Uncertain
# 49                                               Agree
# 40                                            Disagree
# 130                                              Agree
# 89                                               Agree
# 106                                     Strongly Agree
# 7                                                Agree
# 29                                               Agree
#
#     I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 16                                               Agree
# 49                                           Uncertain
# 40                                               Agree
# 130                                  Strongly Disagree
# 89                                               Agree
# 106                                     Strongly Agree
# 7                                                Agree
# 29                                               Agree
#
#     The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 16                                               Agree
# 49                                               Agree
# 40                                           Uncertain
# 130                                              Agree
# 89                                      Strongly Agree
# 106                                              Agree
# 7                                                Agree
# 29                                               Agree
#
#     Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 16                                      Strongly Agree
# 49                                           Uncertain
# 40                                               Agree
# 130                                              Agree
# 89                                      Strongly Agree
# 106                                     Strongly Agree
# 7                                                Agree
# 29                                               Agree
#
#     Taking quizzes and exams online from home was not comfortable and made me nervous.  \
# 16                                      Strongly Agree
# 49                                   Strongly Disagree
# 40                                            Disagree
# 130                                              Agree
# 89                                      Strongly Agree
# 106                                          Uncertain
# 7                                            Uncertain
# 29                                           Uncertain
#
#     grade_sep
# 16       >7.5
# 49       >9.5
# 40       >8.0
# 130      >6.5
# 89       >8.5
# 106      >8.0
# 7        >8.0
# 29       >7.5
#
# [8 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 29 columns):
#  #   Column                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                  --------------  -----
#  0   Roll number                                                                                                                             167 non-null    int64
#  1   Name                                                                                                                                    167 non-null    object
#  2   Department                                                                                                                              167 non-null    object
#  3   Gender                                                                                                                                  167 non-null    object
#  4   Age                                                                                                                                     167 non-null    int64
#  5   sem1_marks                                                                                                                              167 non-null    float64
#  6   sem2_marks                                                                                                                              167 non-null    float64
#  7   sem3_marks                                                                                                                              167 non-null    float64
#  8   sem4_marks                                                                                                                              167 non-null    float64
#  9   Which device you use more frequently                                                                                                    167 non-null    object
#  10  How you study before covid , using printed notes or online notes                                                                        167 non-null    object
#  11  How you study after covid , using printed notes or online notes                                                                         167 non-null    object
#  12  Before COVID-19: How much time do you spend using the digital tools in learning (in hrs) ?                                              167 non-null    object
#  13  After COVID-19: How much time do you spend using the digital tools in learning (in hrs) ?                                               167 non-null    object
#  14  Before COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.                                                        167 non-null    object
#  15  After COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.                                                         167 non-null    object
#  16   When I use the mobile phone, tablet or laptop in e-learning, I cannot concentrate and I am distracted.                                 167 non-null    object
#  17  Before COVID-19: I have fixed hours for bedtime and wake-up.                                                                            167 non-null    object
#  18  After COVID-19: I have fixed hours for bedtime and wake-up.                                                                             167 non-null    object
#  19  Continuous exposure to electronic screens in online learning is tiring and exhausting                                                   167 non-null    object
#  20  The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  167 non-null    object
#  21  Staying home for long periods of time leads to lethargy and laziness.                                                                   167 non-null    object
#  22  Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.                                                     167 non-null    object
#  23  The psychological element is a key factor in the success of the educational process.                                                    167 non-null    object
#  24  I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.                       167 non-null    object
#  25  The volume of assignments via e-learning led to confusion, frustration and poor performance.                                            167 non-null    object
#  26  Face-to-face interaction contributes significantly to boosting students’ academic achievement.                                          167 non-null    object
#  27  Taking quizzes and exams online from home was not comfortable and made me nervous.                                                      167 non-null    object
#  28  grade_sep                                                                                                                               167 non-null    category
# dtypes: category(1), float64(4), int64(2), object(22)
# memory usage: 37.2+ KB

# %%
df.dtypes
# Out:
# Roll number                                                                                                                                  int64
# Name                                                                                                                                        object
# Department                                                                                                                                  object
# Gender                                                                                                                                      object
# Age                                                                                                                                          int64
# sem1_marks                                                                                                                                 float64
# sem2_marks                                                                                                                                 float64
# sem3_marks                                                                                                                                 float64
# sem4_marks                                                                                                                                 float64
# Which device you use more frequently                                                                                                        object
# How you study before covid , using printed notes or online notes                                                                            object
# How you study after covid , using printed notes or online notes                                                                             object
# Before COVID-19: How much time do you spend using the digital tools in learning (in hrs) ?                                                  object
# After COVID-19: How much time do you spend using the digital tools in learning (in hrs) ?                                                   object
# Before COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.                                                            object
# After COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.                                                             object
#  When I use the mobile phone, tablet or laptop in e-learning, I cannot concentrate and I am distracted.                                     object
# Before COVID-19: I have fixed hours for bedtime and wake-up.                                                                                object
# After COVID-19: I have fixed hours for bedtime and wake-up.                                                                                 object
# Continuous exposure to electronic screens in online learning is tiring and exhausting                                                       object
# The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?      object
# Staying home for long periods of time leads to lethargy and laziness.                                                                       object
# Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.                                                         object
# The psychological element is a key factor in the success of the educational process.                                                        object
# I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.                           object
# The volume of assignments via e-learning led to confusion, frustration and poor performance.                                                object
# Face-to-face interaction contributes significantly to boosting students’ academic achievement.                                              object
# Taking quizzes and exams online from home was not comfortable and made me nervous.                                                          object
# grade_sep                                                                                                                                 category
# dtype: object

# %%
df.describe()
# Out:
#         Roll number         Age  sem1_marks   sem2_marks   sem3_marks   \
# count  1.670000e+02  167.000000   167.000000   167.000000   167.000000
# mean   1.932458e+06   19.598802     8.060180     8.416707     8.916048
# std    1.178972e+03    0.560334     0.685667     0.530845     0.590999
# min    1.931001e+06   18.000000     6.700000     6.830000     7.000000
# 25%    1.931050e+06   19.000000     7.540000     8.095000     8.560000
# 50%    1.932043e+06   20.000000     8.040000     8.480000     8.910000
# 75%    1.934008e+06   20.000000     8.520000     8.830000     9.405000
# max    1.934055e+06   21.000000     9.540000     9.380000    10.000000
#
#        sem4_marks
# count   167.000000
# mean      8.823473
# std       0.476440
# min       7.380000
# 25%       8.620000
# 50%       8.900000
# 75%       9.160000
# max      10.000000

# %%
df.corr()
# Out:
#              Roll number       Age  sem1_marks   sem2_marks   sem3_marks   \
# Roll number     1.000000 -0.055465    -0.169399     0.436338    -0.347369
# Age            -0.055465  1.000000     0.016809    -0.096415    -0.031740
# sem1_marks     -0.169399  0.016809     1.000000     0.572491     0.630329
# sem2_marks      0.436338 -0.096415     0.572491     1.000000     0.385119
# sem3_marks     -0.347369 -0.031740     0.630329     0.385119     1.000000
# sem4_marks     -0.495369 -0.017314     0.533440     0.145653     0.706194
#
#              sem4_marks
# Roll number    -0.495369
# Age            -0.017314
# sem1_marks      0.533440
# sem2_marks      0.145653
# sem3_marks      0.706194
# sem4_marks      1.000000

# %%
#Correlation between each semester
df.iloc[5:9,5:9].corr()
# Out:
#              sem1_marks   sem2_marks   sem3_marks   sem4_marks
# sem1_marks      1.000000     0.996847     0.835904     0.876107
# sem2_marks      0.996847     1.000000     0.800714     0.865954
# sem3_marks      0.835904     0.800714     1.000000     0.943023
# sem4_marks      0.876107     0.865954     0.943023     1.000000

# %%
sn.heatmap(df.iloc[5:9,5:9].corr(), linewidths=.8, annot=True)
# Out:
# <AxesSubplot:>

# %%
#GENDER DESCRIPTION

# %%
#show count Gender
df['Gender'].value_counts()
# Out:
# Female    91
# Male      76
# Name: Gender, dtype: int64

# %%
#show Gender's unique
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Gender show bar plot
sn.set(style='whitegrid')
ax=sn.barplot(x=df['Gender'].value_counts().index,y=df['Gender'].value_counts().values,palette="Reds_d",hue=['female','male'])
plt.legend(loc=8)
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Show of Gender Bar Plot')
plt.show()

# %%
#DEPERMENT DESCRIPTION

# %%
plt.figure(figsize=(7,7))
sn.barplot(x=df['Department'].value_counts().index,
              y=df['Department'].value_counts().values)
plt.xlabel('Department')
plt.ylabel('Frequency')
plt.title('Show of Department Bar Plot')
plt.show()

# %%
# MARKS - ALL GPA - DESCRIPTION

# %%
#Calculating Avg of offline exams(Sem 1 and Sem 2)
cols = ['sem1_marks ','sem2_marks ']
df['offline_avg'] =  df[cols].astype(float).mean(axis=1)

# %%
#Calculating Avg of online exams(Sem 1 and Sem 2)
cols = ['sem3_marks ','sem4_marks ']
df['online_avg'] =  df[cols].astype(float).mean(axis=1)

# %%
#Calculating Avg of online exams(Sem 1 and Sem 2)
cols = ['sem1_marks ','sem2_marks ','sem3_marks ','sem4_marks ']
df['avg'] =  df[cols].astype(float).mean(axis=1)

# %%
df
# Out:
#      Roll number         Name Department  Gender  Age  sem1_marks   \
# 0        1931001    Aathish M         SS    Male   19         8.70
# 1        1931002     Adarsh S         SS    Male   19         7.58
# 2        1931003    R. Ahalya         SS  Female   20         8.75
# 3        1931004      Ajhay V         SS    Male   20         8.38
# 4        1931005  D.A.Akshaya         SS  Female   19         8.08
# ..           ...          ...        ...     ...  ...          ...
# 162      1934049       Subash    AI & ML    Male   20         7.09
# 163      1934051     Surya RE    AI & ML    Male   21         6.91
# 164      1934052     TANUJA A    AI & ML  Female   19         7.05
# 165      1934054   Vaishali K    AI & ML  Female   20         7.18
# 166      1934055     Varsha B    AI & ML  Female   19         7.45
#
#      sem2_marks   sem3_marks   sem4_marks   \
# 0           7.90         9.10         8.90
# 1           7.70         9.09         8.73
# 2           8.57         9.55         9.50
# 3           8.45         8.57         8.77
# 4           8.48         8.77         8.64
# ..           ...          ...          ...
# 162         8.52         8.36         8.14
# 163         8.24         8.55         8.10
# 164         8.71         8.05         8.10
# 165         8.62         9.05         8.14
# 166         8.81         8.86         8.62
#
#     Which device you use more frequently  ...  \
# 0                                 Laptop  ...
# 1                                 Laptop  ...
# 2                                 Laptop  ...
# 3                                  Phone  ...
# 4                                 Laptop  ...
# ..                                   ...  ...
# 162                               Laptop  ...
# 163                               Laptop  ...
# 164                                Phone  ...
# 165                                Phone  ...
# 166                                Phone  ...
#
#     Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 0                                            Uncertain
# 1                                    Strongly Disagree
# 2                                                Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     The psychological element is a key factor in the success of the educational process.  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                       Strongly Agree
# 3                                       Strongly Agree
# 4                                            Uncertain
# ..                                                 ...
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                              Agree
# 166                                     Strongly Agree
#
#     I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                             Disagree
# 1                                    Strongly Disagree
# 2                                                Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 162                                          Uncertain
# 163                                  Strongly Disagree
# 164                                  Strongly Disagree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                             Disagree
# 1                                                Agree
# 2                                            Uncertain
# 3                                       Strongly Agree
# 4                                            Uncertain
# ..                                                 ...
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                                Agree
# 1                                                Agree
# 2                                                Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 162                                              Agree
# 163                                     Strongly Agree
# 164                                     Strongly Agree
# 165                                     Strongly Agree
# 166                                     Strongly Agree
#
#     Taking quizzes and exams online from home was not comfortable and made me nervous.  \
# 0                                    Strongly Disagree
# 1                                                Agree
# 2                                            Uncertain
# 3                                       Strongly Agree
# 4                                            Uncertain
# ..                                                 ...
# 162                                              Agree
# 163                                  Strongly Disagree
# 164                                  Strongly Disagree
# 165                                              Agree
# 166                                     Strongly Agree
#
#     grade_sep offline_avg online_avg     avg
# 0        >8.5       8.300      9.000  8.6500
# 1        >7.5       7.640      8.910  8.2750
# 2        >8.5       8.660      9.525  9.0925
# 3        >8.0       8.415      8.670  8.5425
# 4        >8.0       8.280      8.705  8.4925
# ..        ...         ...        ...     ...
# 162      >7.0       7.805      8.250  8.0275
# 163      >6.5       7.575      8.325  7.9500
# 164      >7.0       7.880      8.075  7.9775
# 165      >7.0       7.900      8.595  8.2475
# 166      >7.0       8.130      8.740  8.4350
#
# [167 rows x 32 columns]

# %%
#Counting student, Those who have online_avg > offline_avg
yes,no,l=[],[],[]
for i in range(len(df['Name'])):
    if(df['online_avg'][i]>df['offline_avg'][i]):
        yes.append(df['Name'][i])
        l.append('YES')
    else:
        no.append(df['Name'][i])
        l.append('NO')
        
#Adding to dataframe
df['Online_score_is_greater']= l

# %%
#Counting student, Those who have online_avg > offline_avg
df['Online_score_is_greater'].value_counts()
# Out:
# YES    151
# NO      16
# Name: Online_score_is_greater, dtype: int64

# %%
print('student, Those who have online_avg > offline_avg',len(yes))
print('student, Those who have online_avg < offline_avg',len(no))
# Out:
# student, Those who have online_avg > offline_avg 151
# student, Those who have online_avg < offline_avg 16

# %%
#Gender show bar plot
sn.set(style='whitegrid')
ax=sn.barplot(x=df['Online_score_is_greater'].value_counts().index,y=df['Online_score_is_greater'].value_counts().values,palette="Blues_d",hue=['YES','NO'])
plt.legend(loc=8)
plt.xlabel('Average_Online_Score_is_Greater')
plt.ylabel('No. of Student')
plt.title('Student having Online Average Score more than offline Scores')
plt.show()

# %%
#Checking How much percentage improvement is done
per=[]
for i in range(len(df['Name'])):
    per.append(abs(df['online_avg'][i]-df['offline_avg'][i])*10)
df['Percentge_difference_in_both_modes']=per

# %%
df.head()
# Out:
#    Roll number         Name Department  Gender  Age  sem1_marks   sem2_marks   \
# 0      1931001    Aathish M         SS    Male   19         8.70         7.90
# 1      1931002     Adarsh S         SS    Male   19         7.58         7.70
# 2      1931003    R. Ahalya         SS  Female   20         8.75         8.57
# 3      1931004      Ajhay V         SS    Male   20         8.38         8.45
# 4      1931005  D.A.Akshaya         SS  Female   19         8.08         8.48
#
#    sem3_marks   sem4_marks  Which device you use more frequently  ...  \
# 0         9.10         8.90                               Laptop  ...
# 1         9.09         8.73                               Laptop  ...
# 2         9.55         9.50                               Laptop  ...
# 3         8.57         8.77                                Phone  ...
# 4         8.77         8.64                               Laptop  ...
#
#   I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                           Disagree
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                           Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Taking quizzes and exams online from home was not comfortable and made me nervous.  \
# 0                                  Strongly Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   grade_sep offline_avg online_avg     avg Online_score_is_greater  \
# 0      >8.5       8.300      9.000  8.6500                     YES
# 1      >7.5       7.640      8.910  8.2750                     YES
# 2      >8.5       8.660      9.525  9.0925                     YES
# 3      >8.0       8.415      8.670  8.5425                     YES
# 4      >8.0       8.280      8.705  8.4925                     YES
#
#   Percentge_difference_in_both_modes
# 0                               7.00
# 1                              12.70
# 2                               8.65
# 3                               2.55
# 4                               4.25
#
# [5 rows x 34 columns]

# %%
cc=0
for i in range(len(df['Name'])):
    if(df['Online_score_is_greater'][i]=='YES' and df['Percentge_difference_in_both_modes'][i]>=10):
        cc=cc+1

# %%
print('The number of student, whose percentage difference in both mode is greater than 10% is ',cc)
# Out:
# The number of student, whose percentage difference in both mode is greater than 10% is  42

# %%
print((36/150)*100,'% of Student got 10% percent more marks in 10%.')
# Out:
# 24.0 % of Student got 10% percent more marks in 10%.

# %%
ax1 = df.plot(kind='scatter', x='sem1_marks ', y='sem1_marks ', color='r')    
ax2 = df.plot(kind='scatter', x='sem2_marks ', y='sem1_marks ', color='g', ax=ax1)    
ax3 = df.plot(kind='scatter', x='sem3_marks ', y='sem1_marks ', color='b', ax=ax1)
ax4 = df.plot(kind='scatter', x='sem4_marks ', y='sem1_marks ', color='y', ax=ax1)
print(ax1 == ax2 == ax3 == ax4)
# Out:
# True

# %%
df=pd.read_csv('msc2019b.csv')
#Coverting Float value is multiplyed 100...to int. 
df['sem1_marks '] = (100*df['sem1_marks ']).astype(float).astype(int)
df['sem2_marks '] = (100*df['sem2_marks ']).astype(float).astype(int)
df['sem3_marks '] = (100*df['sem3_marks ']).astype(float).astype(int)
df['sem4_marks '] = (100*df['sem4_marks ']).astype(float).astype(int)

# %%
df.head()
# Out:
#    Roll number         Name Department  Gender  Age  sem1_marks   sem2_marks   \
# 0      1931001    Aathish M         SS    Male   19          869          790
# 1      1931002     Adarsh S         SS    Male   19          758          770
# 2      1931003    R. Ahalya         SS  Female   20          875          857
# 3      1931004      Ajhay V         SS    Male   20          838          844
# 4      1931005  D.A.Akshaya         SS  Female   19          808          848
#
#    sem3_marks   sem4_marks  Which device you use more frequently  ...  \
# 0          910          890                               Laptop  ...
# 1          909          873                               Laptop  ...
# 2          955          950                               Laptop  ...
# 3          857          877                                Phone  ...
# 4          877          864                               Laptop  ...
#
#   After COVID-19: I have fixed hours for bedtime and wake-up.   \
# 0                                              Agree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                     Strongly Agree
#
#   Staying home for long periods of time leads to lethargy and laziness.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 0                                          Uncertain
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The psychological element is a key factor in the success of the educational process.  \
# 0                                     Strongly Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                           Disagree
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                           Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
#   Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly Agree
# 4                                              Agree
#
#   Taking quizzes and exams online from home was not comfortable and made me nervous.
# 0                                  Strongly Disagree
# 1                                              Agree
# 2                                          Uncertain
# 3                                     Strongly Agree
# 4                                          Uncertain
#
# [5 rows x 28 columns]

# %%
l=list(df.columns)

# %%
l[27]
# Out:
# 'Taking quizzes and exams online from home was not comfortable and made me nervous.'

# %%
# Label Encoding
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
 
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['Department']= label_encoder.fit_transform(df['Department'])
df['Age']= label_encoder.fit_transform(df['Age'])    
    
l=list(df.columns)

for i in range(9,28):
    df[l[i]] = label_encoder.fit_transform(df[l[i]])

# %%
df.head()
# Out:
#    Roll number         Name  Department  Gender  Age  sem1_marks   \
# 0      1931001    Aathish M           3       1    1          869
# 1      1931002     Adarsh S           3       1    1          758
# 2      1931003    R. Ahalya           3       0    2          875
# 3      1931004      Ajhay V           3       1    2          838
# 4      1931005  D.A.Akshaya           3       0    1          808
#
#    sem2_marks   sem3_marks   sem4_marks   \
# 0          790          910          890
# 1          770          909          873
# 2          857          955          950
# 3          844          857          877
# 4          848          877          864
#
#    Which device you use more frequently  ...  \
# 0                                     0  ...
# 1                                     0  ...
# 2                                     0  ...
# 3                                     2  ...
# 4                                     0  ...
#
#    After COVID-19: I have fixed hours for bedtime and wake-up.   \
# 0                                                  0
# 1                                                  0
# 2                                                  4
# 3                                                  2
# 4                                                  4
#
#    Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  2
# 4                                                  0
#
#    The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Staying home for long periods of time leads to lethargy and laziness.  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#    Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 0                                                  4
# 1                                                  3
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#    The psychological element is a key factor in the success of the educational process.  \
# 0                                                  2
# 1                                                  0
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                                  1
# 1                                                  3
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#    The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                                  1
# 1                                                  0
# 2                                                  4
# 3                                                  2
# 4                                                  4
#
#    Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#    Taking quizzes and exams online from home was not comfortable and made me nervous.
# 0                                                  3
# 1                                                  0
# 2                                                  4
# 3                                                  2
# 4                                                  4
#
# [5 rows x 28 columns]

# %%
df.drop(columns=['Roll number','Name'], inplace=True)
df
# Out:
#      Department  Gender  Age  sem1_marks   sem2_marks   sem3_marks   \
# 0             3       1    1          869          790          910
# 1             3       1    1          758          770          909
# 2             3       0    2          875          857          955
# 3             3       1    2          838          844          857
# 4             3       0    1          808          848          877
# ..          ...     ...  ...          ...          ...          ...
# 162           0       1    2          709          852          836
# 163           0       1    3          691          824          855
# 164           0       0    1          705          871          805
# 165           0       0    2          718          861          905
# 166           0       0    1          745          881          886
#
#      sem4_marks   Which device you use more frequently  \
# 0            890                                     0
# 1            873                                     0
# 2            950                                     0
# 3            877                                     2
# 4            864                                     0
# ..           ...                                   ...
# 162          814                                     0
# 163          810                                     0
# 164          810                                     2
# 165          814                                     2
# 166          861                                     2
#
#      How you study before covid , using printed notes or online notes  \
# 0                                                    1
# 1                                                    0
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 162                                                  0
# 163                                                  1
# 164                                                  1
# 165                                                  1
# 166                                                  1
#
#      How you study after covid , using printed notes or online notes  ...  \
# 0                                                    0                ...
# 1                                                    0                ...
# 2                                                    0                ...
# 3                                                    0                ...
# 4                                                    0                ...
# ..                                                 ...                ...
# 162                                                  0                ...
# 163                                                  0                ...
# 164                                                  0                ...
# 165                                                  0                ...
# 166                                                  0                ...
#
#      After COVID-19: I have fixed hours for bedtime and wake-up.   \
# 0                                                    0
# 1                                                    0
# 2                                                    4
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 162                                                  4
# 163                                                  1
# 164                                                  1
# 165                                                  4
# 166                                                  3
#
#      Continuous exposure to electronic screens in online learning is tiring and exhausting  \
# 0                                                    0
# 1                                                    0
# 2                                                    2
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  0
# 166                                                  2
#
#      The distance learning system, caused by the COVID-19 epidemic, resulted in social distancing and lesser interaction between students ?  \
# 0                                                    0
# 1                                                    0
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  2
# 166                                                  2
#
#      Staying home for long periods of time leads to lethargy and laziness.  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  2
# 166                                                  2
#
#      Prolonged use of e-learning tools often leads to boredom, nervousness, and tension.  \
# 0                                                    4
# 1                                                    3
# 2                                                    0
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  2
# 166                                                  2
#
#      The psychological element is a key factor in the success of the educational process.  \
# 0                                                    2
# 1                                                    0
# 2                                                    2
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  0
# 166                                                  2
#
#      I don’t recommend continuing with the online learning model because it is socially and psychologically unhealthy.  \
# 0                                                    1
# 1                                                    3
# 2                                                    0
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 162                                                  4
# 163                                                  3
# 164                                                  3
# 165                                                  2
# 166                                                  2
#
#      The volume of assignments via e-learning led to confusion, frustration and poor performance.   \
# 0                                                    1
# 1                                                    0
# 2                                                    4
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  2
# 166                                                  2
#
#      Face-to-face interaction contributes significantly to boosting students’ academic achievement.  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 162                                                  0
# 163                                                  2
# 164                                                  2
# 165                                                  2
# 166                                                  2
#
#      Taking quizzes and exams online from home was not comfortable and made me nervous.
# 0                                                    3
# 1                                                    0
# 2                                                    4
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 162                                                  0
# 163                                                  3
# 164                                                  3
# 165                                                  0
# 166                                                  2
#
# [167 rows x 26 columns]

# %% [markdown]
# ### MODEL SELECTION AND FITTING

# %%
#Feature 
X = df.drop(['sem4_marks ','sem1_marks '], axis=1)
#Target
y = df['sem4_marks ']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()  
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Prediction of test set 
y_pred_mlr= mlr.predict(x_test)
#Predicted values
print("Prediction for test set: {}".format(y_pred_mlr))
# Out:
# Prediction for test set: [857.68742238 888.11796436 893.95955823 902.05684106 894.22960585
#  915.27846436 888.24786693 898.92973961 753.1900244  768.99682478
#  855.75801691 899.92727452 894.02532039 873.49150005 935.05881574
#  860.86865722 833.66120718 875.06238095 814.19413598 887.3338382
#  917.79897442 903.12004338 920.59567273 837.59860322 896.5420698
#  953.20977078 919.79896676 909.93067122 851.3929672  851.78859538
#  914.53283175 853.99741278 838.89555922 796.95114509 841.88752639
#  925.20707158 832.16488434 885.22157074 901.02906315 854.89173495
#  878.47818986 884.73107478 881.243443   920.10111055 866.01164922
#  928.63889251 884.88748967 903.09572659 890.12081402 789.37246412
#  829.61006502]

# %%
#Actual value and the predicted value
mlr_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
#Model Evaluation
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr))
Acc=mlr.score(X,y)*100
print('R squared: {:.2f}'.format(mlr.score(X,y)*100))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 60.33
# Mean Absolute Error: 23.607159060818837
# Mean Square Error: 1117.2494658228582
# Root Mean Square Error: 33.425281836102116

# %%
print('Accuracy:', round(Acc, 2), '%.')
# Out:
# Accuracy: 60.33 %.

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
reg = GradientBoostingRegressor(random_state=0)
reg.fit(X_train, y_train)
reg.predict(X_test[1:2])
ac=reg.score(X_test, y_test)
acc=ac*100
print('Accuracy:', round(acc, 2), '%.')
# Out:
# Accuracy: 58.4 %.

# %% [markdown]
# Extra Trees Regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
ac=reg.score(X_test, y_test)
acc=ac*100
print('Accuracy:', round(acc, 2), '%.')
# Out:
# Accuracy: 74.0 %.

# %% [markdown]
# Random Forest Regressor Model

# %%
from sklearn.model_selection import train_test_split 
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size = 0.25, random_state = 42)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(train_features, train_labels);

# %%
predictions = rf.predict(test_features)
errors = abs(predictions - test_labels)
print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 16.4

# %%
mape = 100 * (errors / test_labels)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 98.17 %.

# %% [markdown]
# ### OUT OF ALL, WE GOT RANDOM FOREST REGRESSOR HAS MAXIMUM ACCURACY OF 97.11%.

# %% [markdown]
# WHY REGRESSOR and WHY NOT OTHER METHODS or MODELs:
#
# Here, We are dealing with marks and related factors which effects the marks. There is a relationship between for sure. as well those relation is in numberical form. Therefore, We are considering Regressor model only.
#
#
# Even if we try any classifier models, we wont get accuracy more than 10-20%,
# Where we can have minimum of 50% accuracy in Regressor. As there exits , a expersional relationship between them.

# %% [markdown]
# So, Here are fitted model to find value of sem4 marks by using previous semester and some other factors.
# Similarly, futher we can predict marks of semester 5 by using the above model.
#
# Formula:
#
# if semester 5 is Online , Then we can directly fit above model and get results:
#
#           Sem5_marks = predicted_sem5_mark
#
# if semester 5 if offline, then result be :
#
#           Sem5_marks = ((sem1_mark x 3) +(predicted_sem5_mark))/4
